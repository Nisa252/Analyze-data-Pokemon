# %%
import pandas as pd

# %%
df = pd.read_csv('Pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df = df.set_index('#')

# %%
df.index
# Out:
# Index([  1,   2,   3,   3,   4,   5,   6,   6,   6,   7,
#        ...
#        714, 715, 716, 717, 718, 719, 719, 720, 720, 721],
#       dtype='int64', name='#', length=800)

# %%
df
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
df[['Name', 'Type 1', 'Type 2', 'Total']]
# Out:
#                       Name   Type 1  Type 2  Total
# #
# 1                Bulbasaur    Grass  Poison    318
# 2                  Ivysaur    Grass  Poison    405
# 3                 Venusaur    Grass  Poison    525
# 3    VenusaurMega Venusaur    Grass  Poison    625
# 4               Charmander     Fire     NaN    309
# ..                     ...      ...     ...    ...
# 719                Diancie     Rock   Fairy    600
# 719    DiancieMega Diancie     Rock   Fairy    700
# 720    HoopaHoopa Confined  Psychic   Ghost    600
# 720     HoopaHoopa Unbound  Psychic    Dark    680
# 721              Volcanion     Fire   Water    600
#
# [800 rows x 4 columns]

# %%
Name_column = df['Name']
Name_column
# Out:
# #
# 1                  Bulbasaur
# 2                    Ivysaur
# 3                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 719                  Diancie
# 719      DiancieMega Diancie
# 720      HoopaHoopa Confined
# 720       HoopaHoopa Unbound
# 721                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
Type_column = df['Type 1']
Type_column
# Out:
# #
# 1        Grass
# 2        Grass
# 3        Grass
# 3        Grass
# 4         Fire
#         ...
# 719       Rock
# 719       Rock
# 720    Psychic
# 720    Psychic
# 721       Fire
# Name: Type 1, Length: 800, dtype: object

# %%
first_row = df.loc[721]
first_row
# Out:
# Name          Volcanion
# Type 1             Fire
# Type 2            Water
# Total               600
# HP                   80
# Attack              110
# Defense             120
# Sp. Atk             130
# Sp. Def              90
# Speed                70
# Generation            6
# Legendary          True
# Name: 721, dtype: object

# %%
first_row = df.iloc[0]
first_row
# Out:
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# Total               318
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 1, dtype: object

# %%
high_Defense_score = df[df['Defense'] > 150].sort_values(by=['Defense'])
high_Defense_score
# Out:
#                       Name   Type 1   Type 2  Total   HP  Attack  Defense  \
# #
# 95                    Onix     Rock   Ground    385   35      45      160
# 383  GroudonPrimal Groudon   Ground     Fire    770  100     180      160
# 386    DeoxysDefense Forme  Psychic      NaN    600   50      70      160
# 411              Bastiodon     Rock    Steel    495   60      52      168
# 80     SlowbroMega Slowbro    Water  Psychic    590   95      75      180
# 91                Cloyster    Water      Ice    525   50      95      180
# 306                 Aggron    Steel     Rock    530   70     110      180
# 713                Avalugg      Ice      NaN    514   95     117      184
# 208                Steelix    Steel   Ground    510   75      85      200
# 377               Regirock     Rock      NaN    580   80     100      200
# 208    SteelixMega Steelix    Steel   Ground    610   75     125      230
# 213                Shuckle      Bug     Rock    505   20      10      230
# ...

# %%
df['Total'].mean()
# Out:
# 435.1025

# %%
df.groupby('Generation')[['HP', 'Attack', 'Defense']].mean()
# Out:
#                    HP     Attack    Defense
# Generation
# 1           65.819277  76.638554  70.861446
# 2           71.207547  72.028302  73.386792
# 3           66.543750  81.625000  74.100000
# 4           73.082645  82.867769  78.132231
# 5           71.787879  82.066667  72.327273
# 6           68.268293  75.804878  76.682927

# %%
df.loc[df.groupby('Generation')['Defense'].idxmax()][['Name','Generation','Defense']]
# Out:
#                     Name  Generation  Defense
# #
# 80               Slowbro           1      110
# 80   SlowbroMega Slowbro           1      180
# 208              Steelix           2      200
# 208  SteelixMega Steelix           2      230
# 306               Aggron           3      180
# 306    AggronMega Aggron           3      230
# 411            Bastiodon           4      168
# 563           Cofagrigus           5      145
# 713              Avalugg           6      184

# %% [markdown]
# VISUALIZATION

# %%
import seaborn as sns
sns.set_theme()

sns.countplot(data=df, x='Total', color='green')
# Out:
# <Axes: xlabel='Total', ylabel='count'>

# %%
sns.boxplot(data=df, x='Name', y='Total')
# Out:
# <Axes: xlabel='Name', ylabel='Total'>

# %%
corr = df[['Generation', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Total']].corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %%
sns.pairplot(df[['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']])
